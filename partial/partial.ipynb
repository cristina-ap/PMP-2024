# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pymc as pm
import arviz as az

# %%
observed_data = ["s","b","b","b","s","b","s","b","b","b"]
obs_data_nr = [1, 0, 0, 0, 1, 0, 1, 0, 0, 0]

alpha = 1
beta = 1

with pm.Model() as first:
    priori = pm.Beta('priori', alpha = 1, beta = 1)
    likelihood = pm.Bernoulli('likelikood', p = priori, observed= obs_data_nr)
    idata1 = pm.sample(1000, tune = 1000, return_inferencedata = True)

az.plot_posterior(idata1, var_names=['priori'])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [priori]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 15 seconds.
# <Axes: title={'center': 'priori'}>

# %%
observed_data = [1,1,0,1,0,0,1,0,0,1]

alpha = 1
beta = 1

with pm.Model() as second:
    priori = pm.Beta('priori', alpha = 1, beta = 1)
    likelihood = pm.Bernoulli('likelikood', p = priori, observed= obs_data_nr)
    idata = pm.sample(1000, tune = 1000, return_inferencedata = True)

az.plot_posterior(idata, var_names=['priori'])
#b
# alpha_posteriori = alpha +     se actualizeaza alpha
# beta_posteriori = beta +      se actualizeaza beta
with pm.Model() as third:
    priori = pm.Beta('priori', alpha = alpha_posteriori, beta = beta_posteriori )
    likelihood = pm.Bernoulli('likelihood', p=priori, observed_data=idata1 )
    idata = pm.sample(1000, tune = 1000, return_inferencedata = True)
az.plot_posterior(idata, var_names=['priori'])
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [priori]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 15 seconds.
# <Axes: title={'center': 'priori'}>
